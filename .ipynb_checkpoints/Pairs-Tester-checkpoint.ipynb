# %%
import numpy as np
import pandas as pd
import pandas_datareader as dr
import matplotlib.pyplot as plt
import yfinance as yf
import seaborn as sn
import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint
import bt
from get_all_tickers import get_tickers as gt
import copy
# %matplotlib inline

# %%
"""Run cell you if want to hide warnings."""
import warnings
warnings.filterwarnings('ignore')

# %%
# Choose dataset to use
chosen_dataset = 'finance'
path = 'prices/{}.csv'.format(chosen_dataset)

# %%
data = pd.read_csv(path, index_col=0)
data.index = pd.to_datetime(data.index)
data.head()
# Out:
#                  ABCB       ACGL      AINV       AMNB       AMSF       ANAT  \
# Date
# 2013-01-02  11.809612  14.793333  9.672423  15.793875  17.655058  53.861610
# 2013-01-03  11.772794  14.750000  9.626857  15.846005  17.519011  54.126022
# 2013-01-04  11.874044  14.876667  9.809139  15.816223  17.636507  54.234890
# 2013-01-07  11.846431  14.730000  9.820533  15.771534  17.333496  54.102684
# 2013-01-08  11.874044  14.750000  9.968637  15.987481  17.253107  54.351551
#
#                 ARCC       AROW       ASPS      ATAX  ...       WHF  \
# Date                                                  ...
# 2013-01-02  7.891840  16.431753  87.760002  3.539224  ...  5.837776
# 2013-01-03  7.922996  16.386366  85.540001  3.574923  ...  5.791134
# 2013-01-04  7.940801  16.490116  86.870003  3.620821  ...  5.826115
# 2013-01-07  7.914094  16.159405  87.510002  3.580021  ...  5.791134
# 2013-01-08  7.909645  16.133469  91.529999  3.544325  ...  5.791134
#
# ...

# %%
import time
import datetime

stocks = data

# Split into train and test sets
split_date ='2019-01-01'
s = datetime.datetime.strptime(split_date,"%Y-%m-%d")
train = stocks.loc[stocks.index < s]
test = stocks.loc[stocks.index >= s]

# %%
"""Retrieve Optimal Pairs"""
import json
path = "optimized_pairs/{}_pairs.json".format(chosen_dataset)
with open(path) as f:
    pairs_data = json.load(f)[chosen_dataset]

# %%
def process_pairs_data(pairs_data, test_data):
    data = []
    test = []
    for pair in pairs_data:
        data.append([pair['stock1'], pair['stock2'], pair['upper'], pair['lower']])
        test.extend([pair['stock1'], pair['stock2']])
    return data, test_data[test]

# %%
processed_pairs, backtest_data = process_pairs_data(pairs_data, test)

# %%
from ipynb.fs.full.Tester import *

tester = Tester(processed_pairs, backtest_data)
tester.run_backtest(True)
# Out:
# Stat                 Pairs Trading     Benchmark
# -------------------  ----------------  -----------
# Start                2019-01-01        2019-01-01
# End                  2021-07-22        2021-07-22
# Risk-free rate       0.00%             0.00%
#
# Total Return         13.23%            46.45%
# Daily Sharpe         0.90              0.59
# Daily Sortino        1.66              0.93
# CAGR                 4.98%             16.11%
# Max Drawdown         -5.57%            -44.27%
# Calmar Ratio         0.89              0.36
#
# MTD                  0.81%             -2.65%
# 3m                   1.30%             -3.28%
# 6m                   0.27%             10.54%
# YTD                  0.06%             20.22%
# 1Y                   2.80%             58.35%
# 3Y (ann.)            4.98%             16.11%
# 5Y (ann.)            -                 -
# 10Y (ann.)           -                 -
# Since Incep. (ann.)  4.98%             16.11%
#
# ...
